# %%
import numpy as np

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('airbnb_data.csv',  low_memory= False)

# %%
pwd
# Out:
# 'C:\\Users\\CHOKO'

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
df.describe()
# Out:
#                  id       host id            lat           long  \
# count  1.025990e+05  1.025990e+05  102591.000000  102591.000000
# mean   2.914623e+07  4.925411e+10      40.728094     -73.949644
# std    1.625751e+07  2.853900e+10       0.055857       0.049521
# min    1.001254e+06  1.236005e+08      40.499790     -74.249840
# 25%    1.508581e+07  2.458333e+10      40.688740     -73.982580
# 50%    2.913660e+07  4.911774e+10      40.722290     -73.954440
# 75%    4.320120e+07  7.399650e+10      40.762760     -73.932350
# max    5.736742e+07  9.876313e+10      40.916970     -73.705220
#
#        Construction year  minimum nights  number of reviews  \
# count      102385.000000   102190.000000      102416.000000
# mean         2012.487464        8.135845          27.483743
# std             5.765556       30.553781          49.508954
# min          2003.000000    -1223.000000           0.000000
# 25%          2007.000000        2.000000           1.000000
# ...

# %%
df.sample(5)
# Out:
#              id                                               NAME  \
# 59265  33733396          Sun filled Brooklyn apartment with a view
# 30160  17658704  Convenient, Quiet and Sunny 1 BR Condo in Flus...
# 39553  22846458             Quiet 1 bedroom near Midtown Manhattan
# 82524  46579341           Newly renovated 2 bedroom with FREE WIFI
# 77628  43875280    Small furnished room in shared West Village apt
#
#            host id host_identity_verified host name neighbourhood group  \
# 59265  25294989715               verified       Fer            Brooklyn
# 30160  68161621761            unconfirmed      Alan              Queens
# 39553  44446417516            unconfirmed    Nicole              Queens
# 82524  68088117878            unconfirmed  Jonathan              Queens
# 77628   1003134054               verified     Sarah           Manhattan
#
#           neighbourhood       lat      long        country country code  \
# ...

# %%
for categoricals in df.columns:
    print(categoricals)
# Out:
# id
# NAME
# host id
# host_identity_verified
# host name
# neighbourhood group
# neighbourhood
# lat
# long
# country
# country code
# instant_bookable
# cancellation_policy
# room type
# Construction year
# price
# service fee
# minimum nights
# number of reviews
# last review
# reviews per month
# review rate number
# calculated host listings count
# availability 365
# house_rules
# license

# %% [markdown]
# #Categorical variable

# %%
categorical_variable = [categoricals for categoricals in df.columns if df[categoricals].dtypes =='object']
categorical_variable
# Out:
# ['NAME',
#  'host_identity_verified',
#  'host name',
#  'neighbourhood group',
#  'neighbourhood',
#  'country',
#  'country code',
#  'instant_bookable',
#  'cancellation_policy',
#  'room type',
#  'price',
#  'service fee',
#  'last review',
#  'house_rules',
#  'license']

# %% [markdown]
# ##numerical variable

# %%
numerical_variable = [categoricals for categoricals in df.columns if df[categoricals].dtypes !='object']
numerical_variable
# Out:
# ['id',
#  'host id',
#  'lat',
#  'long',
#  'Construction year',
#  'minimum nights',
#  'number of reviews',
#  'reviews per month',
#  'review rate number',
#  'calculated host listings count',
#  'availability 365']

# %%
len(numerical_variable)
# Out:
# 11

# %%
print('There are {} categorical variables'.format(len(categorical_variable)))
# Out:
# There are 15 categorical variables

# %% [markdown]
# ## handling missing data

# %%
df.head ()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country country code instant_bookable  \
# ...

# %%
df.isnull ().sum()
# Out:
# id                                     0
# NAME                                 250
# host id                                0
# host_identity_verified               289
# host name                            406
# neighbourhood group                   29
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              532
# country code                         131
# instant_bookable                     105
# cancellation_policy                   76
# room type                              0
# Construction year                    214
# price                                247
# service fee                          273
# minimum nights                       409
# number of reviews                    183
# last review                        15893
# reviews per month                  15879
# review rate number                   326
# calculated host listings count       319
# ...

# %%
df.isnull().sum().sort_values (ascending = False)
# Out:
# license                           102597
# house_rules                        52131
# last review                        15893
# reviews per month                  15879
# country                              532
# availability 365                     448
# minimum nights                       409
# host name                            406
# review rate number                   326
# calculated host listings count       319
# host_identity_verified               289
# service fee                          273
# NAME                                 250
# price                                247
# Construction year                    214
# number of reviews                    183
# country code                         131
# instant_bookable                     105
# cancellation_policy                   76
# neighbourhood group                   29
# neighbourhood                         16
# long                                   8
# lat                                    8
# ...

# %%
len(df)
# Out:
# 102599

# %%
(214/102599) * 100
# Out:
# 0.20857903098470743

# %%
perc_missing = round((df.isnull().sum()/len(df))*100,3).sort_values(ascending = False)
perc_missing
# Out:
# license                           99.998
# house_rules                       50.810
# last review                       15.490
# reviews per month                 15.477
# country                            0.519
# availability 365                   0.437
# minimum nights                     0.399
# host name                          0.396
# review rate number                 0.318
# calculated host listings count     0.311
# host_identity_verified             0.282
# service fee                        0.266
# NAME                               0.244
# price                              0.241
# Construction year                  0.209
# number of reviews                  0.178
# country code                       0.128
# instant_bookable                   0.102
# cancellation_policy                0.074
# neighbourhood group                0.028
# neighbourhood                      0.016
# long                               0.008
# lat                                0.008
# ...

# %%
perc_missing = round((df.isnull().sum()/len(df))*100,3).sort_values(ascending = False)
pd.DataFrame({'Percentage_Missing':perc_missing})
# Out:
#                                 Percentage_Missing
# license                                     99.998
# house_rules                                 50.810
# last review                                 15.490
# reviews per month                           15.477
# country                                      0.519
# availability 365                             0.437
# minimum nights                               0.399
# host name                                    0.396
# review rate number                           0.318
# calculated host listings count               0.311
# host_identity_verified                       0.282
# service fee                                  0.266
# NAME                                         0.244
# price                                        0.241
# Construction year                            0.209
# number of reviews                            0.178
# country code                                 0.128
# ...

# %%
df['license'].isnull()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 102594    True
# 102595    True
# 102596    True
# 102597    True
# 102598    True
# Name: license, Length: 102599, dtype: bool

# %%
df['license'].isnull().sum()
# Out:
# 102597

# %%
df[df['license'].notnull()]
# Out:
#              id                                NAME      host id  \
# 11114   7139598  Cozy 1 BR on Bedford Avenue, Wburg  73023181304
# 72947  41289964  Cozy 1 BR on Bedford Avenue, Wburg  25804773951
#
#       host_identity_verified  host name neighbourhood group neighbourhood  \
# 11114               verified  Christina            Brooklyn  Williamsburg
# 72947            unconfirmed  Christina            Brooklyn  Williamsburg
#
#             lat      long        country country code instant_bookable  \
# 11114  40.71764 -73.95689  United States           US             True
# 72947  40.71764 -73.95689  United States           US             True
#
#       cancellation_policy     room type  Construction year  price service fee  \
# 11114              strict  Private room             2010.0  $702        $140
# 72947            flexible  Private room             2010.0  $702        $140
#
#        minimum nights  number of reviews last review  reviews per month  \
# ...

# %%
df.drop('license', axis=1)
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
df=df.drop('license', axis=1)

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
df.drop(['id', 'long', 'lat', 'country code','house_rules'], axis=1, inplace=True)

# %%
df
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
df['neighbourhood group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'brookln', 'manhatan', 'Queens', nan,
#        'Staten Island', 'Bronx'], dtype=object)

# %%
df['neighbourhood group']=df['neighbourhood group'].replace('brookln','Brooklyn' )

# %%
df['neighbourhood group']=df['neighbourhood group'].replace('manhatan','Manhattan')

# %%
df['neighbourhood group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', nan, 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
df
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
df['price'].isnull(),
# Out:
# (0         False
#  1         False
#  2         False
#  3         False
#  4         False
#            ...
#  102594    False
#  102595    False
#  102596    False
#  102597    False
#  102598    False
#  Name: price, Length: 102599, dtype: bool,)

# %%
df['reviews per month'].unique()
# Out:
# array([ 0.21,  0.38,   nan, ...,  7.73, 24.49, 33.08])

# %%
round (df['reviews per month'].mean(),3)
# Out:
# 1.374

# %%
df['reviews per month']=df['reviews per month'].replace('nan', 1.374)

# %%
df['reviews per month'].fillna(1.374, inplace=True)

# %%
df['reviews per month'].isnull().sum()
# Out:
# 0

# %%
len(df['last review'].mode().sum())
# Out:
# 7

# %%
df['last review'].fillna('6/23/19', inplace=True)

# %%
df
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
df['review rate number'].unique()
# Out:
# array([ 4.,  5.,  3., nan,  2.,  1.])

# %%
df['review rate number'].fillna(5.0, inplace=True)

# %%
df['review rate number']
# Out:
# 0         4.0
# 1         4.0
# 2         5.0
# 3         4.0
# 4         3.0
#          ...
# 102594    3.0
# 102595    2.0
# 102596    5.0
# 102597    3.0
# 102598    3.0
# Name: review rate number, Length: 102599, dtype: float64

# %%
df['review rate number'].unique()
# Out:
# array([4., 5., 3., 2., 1.])
